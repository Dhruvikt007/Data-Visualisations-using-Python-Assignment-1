# %% [markdown]
# ### Name : Dhruvik Satani
# ### LetsUpgrade Assignment - 3

# %% [markdown]
# ### Question 1
# Plot using following plots on fmri data set:
# * sns.relplot
# * line plot
# * box plot

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %% [markdown]
# # Using sns.relplot

# %%
sns.relplot(
    
    x = 'timepoint', y = 'signal', 
    data = fmri, hue = 'subject', 
    size = 'event', style = 'region', 
    col = 'region', row = 'event'
)

# %% [markdown]
# # Using Lineplot

# %%
D = sns.relplot(
    data=fmri,
    x='timepoint', y='signal',
    hue='event', style='event', col='region',
    height=5, aspect=1, kind='line'
)

(D.set_axis_labels("Timepoint", "Percent Signal Change")
  .set_titles("Region: {col_name} Cortex")
  .tight_layout(w_pad=0))

# %% [markdown]
# # Using Boxplot

# %%
sns.catplot(x="timepoint", y="signal",
                hue="region", col="event",
                data=fmri, kind="box",
                height=5, aspect=1);
